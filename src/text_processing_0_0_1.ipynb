# %% [markdown]
# ## Collecting UN Global Compact Communication of Progress (COP) Annual Reports
#
# Web scrapping from [here](https://www.unglobalcompact.org/participation/report/cop/create-and-submit/active) for all COP reports submitted up to 2021. We only take into account the reports submitted in English.

# %% [markdown]
# Last updated on August 19, 2021

# %% [markdown]
# Please specify below the focus year of this analysis:

# %%
focus_year = "2021"

# %% [markdown]
# Please select the focus language using one of the following values:
# - en (English, default option)
# - de (German)
# - es (Spanish)
# - fr (French)
# - pt (Portuguese)

# %%
focus_language = 'en'

# %%
language_ref = { 'en' : { 'name' : 'English', 'min_coocurrence' : 10},
                 'de' : { 'name' : 'German', 'min_coocurrence' : 2},
                 'es' : { 'name' : 'Spanish', 'min_coocurrence' : 2},
                 'fr' : { 'name' : 'French', 'min_coocurrence' : 2},
                 'pt' : { 'name' : 'Portuguese', 'min_coocurrence' : 2},
               }

# %%
import requests
import re
import pandas as pd
import PyPDF2
import shutil
import nltk
import os
import os.path
import requests
from urllib.request import urlretrieve
from bs4 import BeautifulSoup

# %% [markdown]
# ---
# ## Starting point if there is already reports_index.csv file
# This can be used when an index file is available (has been saved previously). Only run this cell if starting from this point, otherwise skip it.

# %%
#load reports_index
reports_index_csv_filename = "reports_index.csv"

df_pdfs = pd.read_csv(reports_index_csv_filename, sep='\t', encoding='utf-8', index_col=0, dtype={'year': object})
pdfs = df_pdfs.to_dict(orient='index')
df_pdfs
# Out:
#                                                         ID  \
# //ungc-production.s3.us-west-2.amazonaws.com/at...  456892
# //ungc-production.s3.us-west-2.amazonaws.com/at...  456891
# //ungc-production.s3.us-west-2.amazonaws.com/at...  456891
# //ungc-production.s3.us-west-2.amazonaws.com/at...  456890
# //ungc-production.s3.us-west-2.amazonaws.com/at...  456890
# ...                                                    ...
# //ungc-production.s3.us-west-2.amazonaws.com/at...   10835
# //ungc-production.s3.us-west-2.amazonaws.com/at...   10835
# //ungc-production.s3.us-west-2.amazonaws.com/at...   10835
# //ungc-production.s3.us-west-2.amazonaws.com/at...   10833
# //ungc-production.s3.us-west-2.amazonaws.com/at...   10832
#
#                                                                      company  \
# //ungc-production.s3.us-west-2.amazonaws.com/at...                  STRATEGO
# //ungc-production.s3.us-west-2.amazonaws.com/at...     Nissan Motor Co. Ltd.
# //ungc-production.s3.us-west-2.amazonaws.com/at...     Nissan Motor Co. Ltd.
# //ungc-production.s3.us-west-2.amazonaws.com/at...  Sapporo Holdings Limited
# //ungc-production.s3.us-west-2.amazonaws.com/at...  Sapporo Holdings Limited
# ...                                                                      ...
# //ungc-production.s3.us-west-2.amazonaws.com/at...         Association COHUB
# //ungc-production.s3.us-west-2.amazonaws.com/at...         Association COHUB
# //ungc-production.s3.us-west-2.amazonaws.com/at...         Association COHUB
# //ungc-production.s3.us-west-2.amazonaws.com/at...         Association COHUB
# //ungc-production.s3.us-west-2.amazonaws.com/at...         Association COHUB
#
#                                                                  sector  \
# //ungc-production.s3.us-west-2.amazonaws.com/at...     Support Services
# //ungc-production.s3.us-west-2.amazonaws.com/at...  Automobiles & Parts
# //ungc-production.s3.us-west-2.amazonaws.com/at...  Automobiles & Parts
# //ungc-production.s3.us-west-2.amazonaws.com/at...            Beverages
# //ungc-production.s3.us-west-2.amazonaws.com/at...            Beverages
# ...                                                                 ...
# //ungc-production.s3.us-west-2.amazonaws.com/at...       Not Applicable
# //ungc-production.s3.us-west-2.amazonaws.com/at...       Not Applicable
# //ungc-production.s3.us-west-2.amazonaws.com/at...       Not Applicable
# //ungc-production.s3.us-west-2.amazonaws.com/at...       Not Applicable
# //ungc-production.s3.us-west-2.amazonaws.com/at...       Not Applicable
#
#                                                    country  year   published  \
# //ungc-production.s3.us-west-2.amazonaws.com/at...  Panama  2021  2021/09/02
# //ungc-production.s3.us-west-2.amazonaws.com/at...   Japan  2021  2021/09/02
# //ungc-production.s3.us-west-2.amazonaws.com/at...   Japan  2021  2021/09/02
# //ungc-production.s3.us-west-2.amazonaws.com/at...   Japan  2021  2021/09/02
# //ungc-production.s3.us-west-2.amazonaws.com/at...   Japan  2021  2021/09/02
# ...                                                    ...   ...         ...
# //ungc-production.s3.us-west-2.amazonaws.com/at...   Benin  2011  2011/02/23
# //ungc-production.s3.us-west-2.amazonaws.com/at...   Benin  2011  2011/02/23
# //ungc-production.s3.us-west-2.amazonaws.com/at...   Benin  2011  2011/02/23
# //ungc-production.s3.us-west-2.amazonaws.com/at...   Benin  2011  2011/02/23
# //ungc-production.s3.us-west-2.amazonaws.com/at...   Benin  2011  2011/02/23
#
#                                                     language sdgs1 sdgs2  \
# //ungc-production.s3.us-west-2.amazonaws.com/at...   Spanish   yes    no
# //ungc-production.s3.us-west-2.amazonaws.com/at...   English   yes   yes
# //ungc-production.s3.us-west-2.amazonaws.com/at...  Japanese   yes   yes
# //ungc-production.s3.us-west-2.amazonaws.com/at...  Japanese    no   yes
# //ungc-production.s3.us-west-2.amazonaws.com/at...  Japanese    no   yes
# ...                                                      ...   ...   ...
# //ungc-production.s3.us-west-2.amazonaws.com/at...    French    no    no
# //ungc-production.s3.us-west-2.amazonaws.com/at...    French    no    no
# //ungc-production.s3.us-west-2.amazonaws.com/at...    French    no    no
# //ungc-production.s3.us-west-2.amazonaws.com/at...    French    no    no
# //ungc-production.s3.us-west-2.amazonaws.com/at...    French    no    no
#
#                                                    sdgs3  ... sdgs8 sdgs9  \
# //ungc-production.s3.us-west-2.amazonaws.com/at...   yes  ...   yes    no
# //ungc-production.s3.us-west-2.amazonaws.com/at...   yes  ...   yes   yes
# //ungc-production.s3.us-west-2.amazonaws.com/at...   yes  ...   yes   yes
# //ungc-production.s3.us-west-2.amazonaws.com/at...   yes  ...   yes    no
# //ungc-production.s3.us-west-2.amazonaws.com/at...   yes  ...   yes    no
# ...                                                  ...  ...   ...   ...
# //ungc-production.s3.us-west-2.amazonaws.com/at...    no  ...    no    no
# //ungc-production.s3.us-west-2.amazonaws.com/at...    no  ...    no    no
# //ungc-production.s3.us-west-2.amazonaws.com/at...    no  ...    no    no
# //ungc-production.s3.us-west-2.amazonaws.com/at...    no  ...    no    no
# //ungc-production.s3.us-west-2.amazonaws.com/at...    no  ...    no    no
#
#                                                    sdgs10 sdgs11 sdgs12  \
# //ungc-production.s3.us-west-2.amazonaws.com/at...    yes     no    yes
# //ungc-production.s3.us-west-2.amazonaws.com/at...    yes    yes    yes
# //ungc-production.s3.us-west-2.amazonaws.com/at...    yes    yes    yes
# //ungc-production.s3.us-west-2.amazonaws.com/at...    yes    yes    yes
# //ungc-production.s3.us-west-2.amazonaws.com/at...    yes    yes    yes
# ...                                                   ...    ...    ...
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no     no     no
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no     no     no
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no     no     no
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no     no     no
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no     no     no
#
#                                                    sdgs13 sdgs14 sdgs15  \
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no     no     no
# //ungc-production.s3.us-west-2.amazonaws.com/at...    yes    yes    yes
# //ungc-production.s3.us-west-2.amazonaws.com/at...    yes    yes    yes
# //ungc-production.s3.us-west-2.amazonaws.com/at...    yes    yes    yes
# //ungc-production.s3.us-west-2.amazonaws.com/at...    yes    yes    yes
# ...                                                   ...    ...    ...
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no     no     no
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no     no     no
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no     no     no
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no     no     no
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no     no     no
#
#                                                    sdgs16 sdgs17
# //ungc-production.s3.us-west-2.amazonaws.com/at...    yes    yes
# //ungc-production.s3.us-west-2.amazonaws.com/at...    yes    yes
# //ungc-production.s3.us-west-2.amazonaws.com/at...    yes    yes
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no    yes
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no    yes
# ...                                                   ...    ...
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no     no
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no     no
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no     no
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no     no
# //ungc-production.s3.us-west-2.amazonaws.com/at...     no     no
#
# [53337 rows x 24 columns]

# %%
companies = {}
countries = {}
sectors = {}
years = {}
languages = {}


for pdf in pdfs.keys():
    company = pdfs[pdf]["company"]
    language = pdfs[pdf]["language"]
    year = pdfs[pdf]["year"]
    country = pdfs[pdf]["country"]
    sector = pdfs[pdf]["sector"]

    companies[company] = companies.get(company,0) + 1
    sectors[sector] = sectors.get(sector,0) + 1
    countries[country] = countries.get(country,0) + 1
    years[year] = years.get(year,0) + 1
    languages[language] = languages.get(language,0) + 1

# %%
selected_companies = {}
selected_sectors = {}
selected_countries = {}
selected_years = {}
selected_countries_years = {}

selected_pdfs = {}

for pdf in pdfs.keys():
    company = pdfs[pdf]["company"]
    language = pdfs[pdf]["language"]
    year = pdfs[pdf]["year"]
    country = pdfs[pdf]["country"]
    sector = pdfs[pdf]["sector"]

#    if language == language_ref[focus_language]['name'] and int(year) <= int(focus_year):
    if language == language_ref[focus_language]['name'] and int(year) <= int(focus_year): #only for the focus_year
        selected_pdfs[pdf] = pdfs[pdf]
        
        selected_companies[company] = selected_companies.get(company,0) + 1
        selected_sectors[sector] = selected_sectors.get(sector,0) + 1
        selected_countries[country] = selected_countries.get(country,0) + 1
        selected_years[year] = selected_years.get(year,0) + 1
        if country in selected_countries_years.keys():
            selected_countries_years[country][year] = selected_countries_years[country].get(year,0) + 1
        else:
            selected_countries_years[country] = {year : 1}

# %%
pdfs_folder = "../data/pdf/"

# %%
txts_folder = "../data/txt/"

# %% [markdown]
# ### Analyzing the text of reports: DataFrame

# %%
os.stat(pdfs_folder)
# Out:
# os.stat_result(st_mode=16895, st_ino=3659174697993395, st_dev=517161065, st_nlink=1, st_uid=0, st_gid=0, st_size=0, st_atime=1629353715, st_mtime=1629353715, st_ctime=1629353715)

# %%
from collections import defaultdict
from pathlib import Path
import pandas as pd

results = defaultdict(list)

for file in Path(txts_folder).iterdir():
    with open(file, "r") as file_open:
        results["file_name"].append(file.name)
        results["text"].append(file_open.read())

df = pd.DataFrame(results)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
