# %% [markdown]
# ### Text Pre-processing

# %%
import pandas as pd
import sys
import csv
import re
maxInt = sys.maxsize

while True:
    try:
        csv.field_size_limit(maxInt)
        break
    except OverflowError:
        maxInt = int(maxInt/10)

# %%
df_extracted = pd.read_csv('df_extracted.csv', engine='python', encoding='utf-8', error_bad_lines=False)

# %%
df_extracted.describe()
# Out:
#          Unnamed: 0         count
# count  18977.000000  1.897700e+04
# mean   11927.675344  9.184705e+04
# std     6883.190923  1.599096e+05
# min        0.000000  1.010000e+02
# 25%     5946.000000  1.025200e+04
# 50%    11961.000000  2.830500e+04
# 75%    17885.000000  1.055390e+05
# max    23795.000000  2.708538e+06

# %%
df_extracted
# Out:
#        Unnamed: 0                                          file_name  \
# 0               0  OLVEA - OLVEAct Now Report - EN - 2019-20.pdf.txt
# 1               1                        20150416_COP_N°5_EN.pdf.txt
# 2               2              2017_report_-_FINAL__UNLOCKED.pdf.txt
# 3               3          COP_Report_SMART_-_Apr_2013_final.pdf.txt
# 4               4                               cop_ETS_2019.pdf.txt
# ...           ...                                                ...
# 18972       23789                            CSR_Report_2014.pdf.txt
# 18973       23792        Nilorngruppen_Sustainability_report.pdf.txt
# 18974       23793                                MM_CSR_2018.pdf.txt
# 18975       23794                      AmatheonAgri-COP-2017.pdf.txt
# 18976       23795                     Letter_COP_CEO_Oct2014.pdf.txt
#
#                                               clean_text   count
# 0      CORPORATE SOCIAL RESPONSIBILITY PERFORMANCE RE...   29122
# 1      Sustainable development the energy that fuels ...   11939
# 2      The whole or any part of this work may not be ...  226975
# 3      PTSinarMasAgro Resources andTechnology TbkGlob...   37025
# 4      Eser Contracting and Industry Co. Inc. Communi...   35188
# ...                                                  ...     ...
# 18972  AH Industries Corporate Social R esponsibility...   39306
# 18973  1More fit for the future SUSTAINABILITY REPORT...  112118
# 18974  ANNUAL CORPORATE SOCIAL RESPONSIBILITY REPORT ...   39360
# 18975  01AMATHEON AGRI COMMUNICATION ON PROGRESS 2017...   21804
# 18976  24 th October 2014 To our stakeholders I am pl...     586
#
# [18977 rows x 4 columns]

# %%
#Remove .txt extension on the file_name column
df_extracted['file_name'] = df_extracted['file_name'].str.replace(r'.txt$', '')
df_extracted
# Out:
#        Unnamed: 0                                      file_name  \
# 0               0  OLVEA - OLVEAct Now Report - EN - 2019-20.pdf
# 1               1                        20150416_COP_N°5_EN.pdf
# 2               2              2017_report_-_FINAL__UNLOCKED.pdf
# 3               3          COP_Report_SMART_-_Apr_2013_final.pdf
# 4               4                               cop_ETS_2019.pdf
# ...           ...                                            ...
# 18972       23789                            CSR_Report_2014.pdf
# 18973       23792        Nilorngruppen_Sustainability_report.pdf
# 18974       23793                                MM_CSR_2018.pdf
# 18975       23794                      AmatheonAgri-COP-2017.pdf
# 18976       23795                     Letter_COP_CEO_Oct2014.pdf
#
#                                               clean_text   count
# 0      CORPORATE SOCIAL RESPONSIBILITY PERFORMANCE RE...   29122
# 1      Sustainable development the energy that fuels ...   11939
# 2      The whole or any part of this work may not be ...  226975
# 3      PTSinarMasAgro Resources andTechnology TbkGlob...   37025
# 4      Eser Contracting and Industry Co. Inc. Communi...   35188
# ...                                                  ...     ...
# 18972  AH Industries Corporate Social R esponsibility...   39306
# 18973  1More fit for the future SUSTAINABILITY REPORT...  112118
# 18974  ANNUAL CORPORATE SOCIAL RESPONSIBILITY REPORT ...   39360
# 18975  01AMATHEON AGRI COMMUNICATION ON PROGRESS 2017...   21804
# 18976  24 th October 2014 To our stakeholders I am pl...     586
#
# [18977 rows x 4 columns]

# %%
# Lower all text contents
df_extracted['text'] = df_extracted['text'].str.lower()
df_extracted
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-43adb65f80e7> in <module>
#       1 # Lower all text contents
# ----> 2 df_extracted['text'] = df_extracted['text'].str.lower()
#       3 df_extracted
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text'

# %%
# replace special special character
df_extracted['text'] = df_extracted['text'].str.replace("\n","").replace("\t"," ").replace("\x0c"," ").replace(".",". ").replace(',',"").replace("\r\n"," ")
df_extracted['text'] = df_extracted['text'].str.replace("\r"," ")
df_extracted
# Out:
#                                                file_name  \
# 0          OLVEA - OLVEAct Now Report - EN - 2019-20.pdf
# 1                                20150416_COP_N°5_EN.pdf
# 2                      2017_report_-_FINAL__UNLOCKED.pdf
# 3                  COP_Report_SMART_-_Apr_2013_final.pdf
# 4                                       cop_ETS_2019.pdf
# ...                                                  ...
# 23791  JCCCSA_-_COMUNICACIÓN_DE_PROGRESO_PARA_EL_PACT...
# 23792            Nilorngruppen_Sustainability_report.pdf
# 23793                                    MM_CSR_2018.pdf
# 23794                          AmatheonAgri-COP-2017.pdf
# 23795                         Letter_COP_CEO_Oct2014.pdf
#
#                                                     text
# 0      corporate  social  responsibility performance ...
# 1          sustainable development, the energy that f...
# 2      ˜˚˛˚˝˙˜˚ˆ˝˝˚˙˜˚˛˚˝˙˜˚ˆ˝˝˚˙˜˚ˆ˝˝˚˜˜˜˚˛˝˙˝ˆ˛˝ˇˆˆ...
# 3      ptsinarmasagroresourcesandtechnologytbkglobalc...
# 4          eser contracting and industry co.inc. comm...
# ...                                                  ...
# 23791
# 23792  _1more fit for the futuresustainability report...
# 23793  annual corporate social responsibility report2...
# 23794  01amatheon agricommunicationon progress 2017gr...
# 23795          24th october 2014      to our stakehol...
#
# [23796 rows x 2 columns]

# %%
df_extracted.to_csv('df_extracted_cleaned.csv')

# %%
pd.read_csv('df_extracted_cleaned.csv', engine='python', encoding='utf-8', error_bad_lines=False)
# Out:
#    Unnamed: 0                                          file_name  \
# 0           0  OLVEA - OLVEAct Now Report - EN - 2019-20.pdf.txt
# 1           1                        20150416_COP_N°5_EN.pdf.txt
# 2           2              2017_report_-_FINAL__UNLOCKED.pdf.txt
# 3           3          COP_Report_SMART_-_Apr_2013_final.pdf.txt
# 4           4                               cop_ETS_2019.pdf.txt
# 5           5                   Orkla_Annual_Report_2014.pdf.txt
# 6           6                         COP_TT-SE_20140318.pdf.txt
# 7           7        Tabadlab Communication on Progress .pdf.txt
# 8           8                      GRUPO_CLARIN_COP_2017.pdf.txt
# 9           9                             2020_report_en.pdf.txt
#
#                                                 text  \
# 0  corporate  social  responsibility  performance...
# 1          sustainable development, the energy th...
# 2  ˜˚˛˚˝˙˜˚ˆ˝˝˚˙˜˚˛˚˝˙˜˚ˆ˝˝˚˙˜˚ˆ˝˝˚˜˜˜˚˛˝˙˝ˆ˛˝ˇˆˆ...
# 3  ptsinarmasagro resources andtechnology tbkglob...
# 4          eser contracting and industry co.inc. ...
# 5  annual report2014 contents03 about orkla 06 me...
# 6                                                NaN
# 7     !!"#"$%"#&'()*"+,&-).)+,$ /&0,11"2)2,&3%44(...
# 8  1     company name :   grupo clarín s.a.    co...
# 9  integrated solutions fora better life 2020 int...
#
#                                              Matches
# 0  {'DATE': '2019', 'ORG': 'saint léonard - franc...
# 1  {'DATE': '2015', 'ORG': 'asnières - sur - sein...
# 2  {'ORDINAL': 'third', 'ORG': 'llc', 'DATE': '22...
# 3  {'PERSON': 'thispolicyalsoappliestoemployees w...
# 4  {'CARDINAL': '10', 'ORG': 'subje ct', 'DATE': ...
# 5  {'DATE': '© 2014', 'ORG': 'no-0276 oslo', 'CAR...
# 6                                                 {}
# 7  {'MONEY': '#"$%', 'ORG': '& &&&&&&', 'WORK_OF_...
# 8  {'CARDINAL': '24,419.13', 'ORG': 'm3         1...
# 9  {'DATE': '2021', 'ORG': 'fsc tm(forest steward...
